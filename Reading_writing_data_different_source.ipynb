# %%
import pandas as pd

# %%
#Reading the csv files intp dataframe
df = pd.read_csv("survey_results_public.csv",index_col = "ResponseId")
df_schema = pd.read_csv("survey_results_schema.csv",index_col ="qid")

# %%
df_schema.head()
# Out:
#            qname                                           question  \
# qid
# QID16         S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12   MetaInfo                                  Browser Meta Info
# QID310      Q310  <div><span style="font-size:19px;"><strong>You...
# QID312      Q120
# QID1          S1  <span style="font-size:22px; font-family: aria...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID310      False    DB       TB
# QID312       True    MC     SAVR
# QID1        False    DB       TB

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows',80)

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %% [markdown]
# #Filtering the dataframe for USA

# %%
filt = (df["Country"]== "United States of America")

# %%
us_df = df.loc[filt]

# %%
us_df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 7           I agree  I am a developer by profession  35-44 years old
# 8           I agree  I am a developer by profession  25-34 years old
#
#                      Employment                            RemoteWork  \
# ResponseId
# 2           Employed, full-time                                Remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time  Hybrid (some remote, some in-person)
# 7           Employed, full-time                                Remote
# 8           Employed, full-time                                Remote
#
#                                              CodingActivities  \
# ResponseId
# ...

# %%
#we are saving the data in csv format
us_df.to_csv("usa_data")

# %%
us_df.to_csv("usa_data",sep ="\t")

# %%
#write to an excel file.
us_df.to_excel("usa_data.xlsx")

# %%
#reading the same excel file that has been created
new_data = pd.read_excel("usa_data.xlsx")#us_df.to_excel("usa_data.xlsx")

# %%
new_data.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           2  I agree  I am a developer by profession  25-34 years old
# 1           3  I agree  I am a developer by profession  45-54 years old
# 2           4  I agree  I am a developer by profession  25-34 years old
# 3           7  I agree  I am a developer by profession  35-44 years old
# 4           8  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 0  Employed, full-time                                Remote
# 1  Employed, full-time  Hybrid (some remote, some in-person)
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                                Remote
# 4  Employed, full-time                                Remote
#
#                                     CodingActivities  \
# 0  Hobby;Contribute to open-source projects;Boots...
# 1  Hobby;Professional development or self-paced l...
# ...

# %%
#Saving the file in jason format.
us_df.to_json("usa_data.json")

# %%
#Json to be list like instead of dictionary like
us_df.to_json("usa_data.json",orient="records",lines = True)

# %%
#Reading the json file.
text = pd.read_json("usa_data.json",orient="records",lines = True)

# %%
text.head()
# Out:
#       Q120                      MainBranch              Age  \
# 0  I agree  I am a developer by profession  25-34 years old
# 1  I agree  I am a developer by profession  45-54 years old
# 2  I agree  I am a developer by profession  25-34 years old
# 3  I agree  I am a developer by profession  35-44 years old
# 4  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 0  Employed, full-time                                Remote
# 1  Employed, full-time  Hybrid (some remote, some in-person)
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                                Remote
# 4  Employed, full-time                                Remote
#
#                                     CodingActivities  \
# 0  Hobby;Contribute to open-source projects;Boots...
# 1  Hobby;Professional development or self-paced l...
# 2                                              Hobby
# ...
