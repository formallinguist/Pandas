# %%
import pandas as pd

# %%
#Reading the csv files intp dataframe
df = pd.read_csv("survey_results_public.csv")
df_schema = pd.read_csv("survey_results_schema.csv")

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows',80)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df["ConvertedCompYearly"].head(15)
# Out:
# 0          NaN
# 1     285000.0
# 2     250000.0
# 3     156000.0
# 4      23456.0
# 5      96828.0
# 6     135000.0
# 7      80000.0
# 8      64254.0
# 9          NaN
# 10         NaN
# 11     78003.0
# 12     75000.0
# 13    150000.0
# 14    187407.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df["ConvertedCompYearly"].median() # we are taking median of that particular coloumn.
# Out:
# 74963.0

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
df["ConvertedCompYearly"].count()
# Out:
# 48019

# %%
df["AISelect"]
# Out:
# 0                            NaN
# 1                            Yes
# 2        No, and I don't plan to
# 3        No, and I don't plan to
# 4                            Yes
#                   ...
# 89179                        Yes
# 89180                        Yes
# 89181     No, but I plan to soon
# 89182                        Yes
# 89183                        Yes
# Name: AISelect, Length: 89184, dtype: object

# %%
df["AISelect"].value_counts()
# Out:
# AISelect
# Yes                        39042
# No, and I don't plan to    26221
# No, but I plan to soon     22710
# Name: count, dtype: int64

# %%
df["LanguageWantToWorkWith"]
# Out:
# 0                                                      NaN
# 1        Bash/Shell (all shells);C#;Dart;Elixir;GDScrip...
# 2                                       Haskell;OCaml;Rust
# 3        Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 4               HTML/CSS;JavaScript;Python;Rust;TypeScript
#                                ...
# 89179    Bash/Shell (all shells);C;Go;HTML/CSS;JavaScri...
# 89180                Java;JavaScript;Python;SQL;TypeScript
# 89181                                          Python;Rust
# 89182    Bash/Shell (all shells);HTML/CSS;JavaScript;Po...
# 89183                      C#;Go;JavaScript;SQL;TypeScript
# Name: LanguageWantToWorkWith, Length: 89184, dtype: object

# %%
df["LanguageWantToWorkWith"].value_counts()
# Out:
# LanguageWantToWorkWith
# Rust                                                                        1438
# Python                                                                      1182
# HTML/CSS;JavaScript;TypeScript                                              1071
# C#                                                                           736
# Go                                                                           618
#                                                                             ...
# Bash/Shell (all shells);Java;JavaScript;MATLAB;SQL;TypeScript                  1
# Java;PowerShell;SQL;VBA                                                        1
# Bash/Shell (all shells);Clojure;Haskell;Java;Objective-C;OCaml;Scala           1
# Bash/Shell (all shells);Haskell;Rust;Scala;SQL;Zig                             1
# Bash/Shell (all shells);C++;HTML/CSS;Java;JavaScript;PHP;Rust;TypeScript       1
# Name: count, Length: 29602, dtype: int64

# %%
df["LanguageWantToWorkWith"].value_counts(normalize=True)
# Out:
# LanguageWantToWorkWith
# Rust                                                                        0.017817
# Python                                                                      0.014645
# HTML/CSS;JavaScript;TypeScript                                              0.013270
# C#                                                                          0.009119
# Go                                                                          0.007657
#                                                                               ...
# Bash/Shell (all shells);Java;JavaScript;MATLAB;SQL;TypeScript               0.000012
# Java;PowerShell;SQL;VBA                                                     0.000012
# Bash/Shell (all shells);Clojure;Haskell;Java;Objective-C;OCaml;Scala        0.000012
# Bash/Shell (all shells);Haskell;Rust;Scala;SQL;Zig                          0.000012
# Bash/Shell (all shells);C++;HTML/CSS;Java;JavaScript;PHP;Rust;TypeScript    0.000012
# ...

# %%
df["Country"].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Liechtenstein                                               1
# Grenada                                                     1
# Central African Republic                                    1
# Guinea-Bissau                                               1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_group  = df.groupby(["Country"]) #Data is grouped based on the country.

# %%
country_group.get_group("India") # Data is grouped by country india
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 9              10  I agree                     I am a developer by profession
# 66             67  I agree                     I am a developer by profession
# 78             79  I agree                     I am a developer by profession
# 82             83  I agree                     I am a developer by profession
# 85             86  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89119       89120  I agree                     I am a developer by profession
# 89121       89122  I agree  I am not primarily a developer, but I write co...
# 89164       89165  I agree                     I am a developer by profession
# 89165       89166  I agree                     I am a developer by profession
# 89167       89168  I agree                     I am a developer by profession
#
# ...

# %%
#We can get the data based on country.
filt = df["Country"] == "United States of America"
df.loc[filt]
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 1               2  I agree                     I am a developer by profession
# 2               3  I agree                     I am a developer by profession
# 3               4  I agree                     I am a developer by profession
# 6               7  I agree                     I am a developer by profession
# 7               8  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89150       89151  I agree  I used to be a developer by profession, but no...
# 89154       89155  I agree                     I am a developer by profession
# 89156       89157  I agree                     I am a developer by profession
# 89175       89176  I agree                     I am a developer by profession
# 89178       89179  I agree                     I am a developer by profession
#
# ...

# %%
country_group['Employment'].value_counts().head(10) #Seeing the top 10
# Out:
# Country      Employment
# Afghanistan  Employed, full-time                                                                                                                                                                                             22
#              Independent contractor, freelancer, or self-employed                                                                                                                                                             8
#              Not employed, but looking for work                                                                                                                                                                               5
#              I prefer not to say                                                                                                                                                                                              5
# ...

# %%
country_group["ConvertedCompYearly"].median().loc['Germany']
# Out:
# 74963.0

# %%
country_group["ConvertedCompYearly"].agg(['median','mean']).loc['Canada']
# Out:
# median     89222.000000
# mean      142136.677435
# Name: Canada, dtype: float64

# %%
filt = df["Country"] == "United States of America"
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum() #Checking the if pyhton is there or not
# Out:
# 10062

# %%
country_group["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %% [markdown]
# #Finding out what percentage of people in a country use python.

# %%
country_respon = df['Country'].value_counts()
country_respon
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Liechtenstein                                               1
# Grenada                                                     1
# Central African Republic                                    1
# Guinea-Bissau                                               1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
Country_uses_python = country_group["LanguageHaveWorkedWith"].apply(lambda x: x.str.contains('Python').sum())
Country_uses_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  35
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                174
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
df_python = pd.concat([Country_uses_python,country_respon],axis="columns",sort=False)

# %%
df_python
# Out:
#                                       LanguageHaveWorkedWith  count
# Country
# Afghanistan                                               22     64
# Albania                                                   19     60
# Algeria                                                   35     85
# Andorra                                                    5     16
# Angola                                                     4     13
# ...                                                      ...    ...
# Venezuela, Bolivarian Republic of...                      42    106
# Viet Nam                                                 174    390
# Yemen                                                      8     20
# Zambia                                                    11     26
# Zimbabwe                                                  19     34
#
# [185 rows x 2 columns]

# %%
#Renaming coloumns.
df_python.rename(columns={"Country":"NumRespondents","LanguageHaveWorkedWith":"NumKnowsPython"})
# Out:
#                                       NumKnowsPython  count
# Country
# Afghanistan                                       22     64
# Albania                                           19     60
# Algeria                                           35     85
# Andorra                                            5     16
# Angola                                             4     13
# ...                                              ...    ...
# Venezuela, Bolivarian Republic of...              42    106
# Viet Nam                                         174    390
# Yemen                                              8     20
# Zambia                                            11     26
# Zimbabwe                                          19     34
#
# [185 rows x 2 columns]

# %%
df_python
# Out:
#                                       LanguageHaveWorkedWith  count
# Country
# Afghanistan                                               22     64
# Albania                                                   19     60
# Algeria                                                   35     85
# Andorra                                                    5     16
# Angola                                                     4     13
# ...                                                      ...    ...
# Venezuela, Bolivarian Republic of...                      42    106
# Viet Nam                                                 174    390
# Yemen                                                      8     20
# Zambia                                                    11     26
# Zimbabwe                                                  19     34
#
# [185 rows x 2 columns]

# %%
df_python["Percentage_knows_python"] = (df_python["count"]/df_python["LanguageHaveWorkedWith"]) * 100

# %%
df_python
# Out:
#                                       LanguageHaveWorkedWith  count  \
# Country
# Afghanistan                                               22     64
# Albania                                                   19     60
# Algeria                                                   35     85
# Andorra                                                    5     16
# Angola                                                     4     13
# ...                                                      ...    ...
# Venezuela, Bolivarian Republic of...                      42    106
# Viet Nam                                                 174    390
# Yemen                                                      8     20
# Zambia                                                    11     26
# Zimbabwe                                                  19     34
#
#                                       Percentage_knows_python
# Country
# Afghanistan                                        290.909091
# ...

# %%
df_python.sort_values(by="Percentage_knows_python",ascending=False,inplace=True)

# %%
df_python.head(17)
# Out:
#                                        LanguageHaveWorkedWith  count  \
# Country
# Central African Republic                                    0      1
# Saint Kitts and Nevis                                       0      1
# Marshall Islands                                            0      1
# Gabon                                                       0      2
# Suriname                                                    0      4
# Guinea                                                      0      2
# Guinea-Bissau                                               0      1
# Monaco                                                      0      2
# Democratic People's Republic of Korea                       0      2
# Djibouti                                                    0      2
# Bahamas                                                     0      2
# Niger                                                       0      4
# ...

# %%
df_python.loc["Japan"]
# Out:
# LanguageHaveWorkedWith     188.000000
# count                      362.000000
# Percentage_knows_python    192.553191
# Name: Japan, dtype: float64
